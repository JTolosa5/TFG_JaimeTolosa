# %%
import pandas as pd 
import numpy as np

# %%
def montardataset(direccion,num):
    cont = 1
    df = pd.read_csv(direccion+str(cont)+'.txt',encoding = 'utf-16', index_col= False)
    cont+=1
    for i in range(cont,num+1):
        dfaux=pd.read_csv(direccion+str(i)+'.txt',encoding = 'utf-16',index_col = False)
        df = pd.concat([df,dfaux],ignore_index=True) # si no tomara la primera columna como el index
    
    return df

# %%
concurso = montardataset('../Datasets/Parcialesv2/Concurso-',11)

# %%
concurso.shape
# Out:
# (5506, 283)

# %%
concurso = concurso.drop(['Mark'],axis=1)

# %%
concurso.duplicated().any()
# Out:
# False

# %%
concurso.to_csv('../Datasets/Concursosv2.csv',index=False)

# %%
concurso.head()
# Out:
#                            Nombre    Localidad    Comunidad autónoma  \
# 0  CORSAN-CORVIAM CONSTRUCCION SA       MADRID                Madrid
# 1                        CODYT SA    BARCELONA              Cataluña
# 2             O W BUNKER SPAIN SL       MADRID                Madrid
# 3          THYSSEN ROS CASARES SA         PUIG  Comunidad Valenciana
# 4                ADVEO ESPAÑA SA.  TRES CANTOS                Madrid
#
#   Código NIF     Forma jurídica    Estado Ultimo año disponible  \
# 0  A79222709   Sociedad anonima  Concurso            31/12/2017
# 1  A58358177   Sociedad anonima  Concurso            31/12/2009
# 2  B84546415  Sociedad limitada  Concurso            31/12/2013
# 3  A46467965   Sociedad anonima  Concurso            30/09/2012
# 4  A82351867   Sociedad anonima  Concurso            31/12/2016
#
#    Código primario CNAE 2009  Ingresos de explotación EUR Año - 2  \
# 0                     4110.0                          450857000.0
# ...

# %%
direccion = '../Datasets/Parciales/Activa-'
num = 62
activa = montardataset(direccion=direccion,num=num)

# %%
activa.shape

# %%
activa.duplicated().any()

# %%
activa.describe()

# %%
activa['Ultimo año disponible'].unique()

# %%
dataset =  pd.concat([concurso,activa])

# %%
dataset.shape

# %%
dataset = dataset.drop(['Mark','Nombre.1'],axis=1)

# %%
dataset.to_csv('../Datasets/Empresas_SABI.csv',index=False)

# %%
dataset.shape

# %%
df = pd.read_csv('../Datasets/Empresas_SABI.csv')

# %%
df.head()

# %%
df.shape

# %% [markdown]
#  ## -------------------------------- Activas v2 ------------------------------

# %%
activas = montardataset('../Datasets/Parcialesv2/Activa-',55)

# %%
activas.head()
# Out:
#    Mark                                         Nombre Código NIF  \
# 0     1                                   MERCADONA SA  A46103834
# 1     2                             REPSOL PETROLEO SA  A28047223
# 2     3             COMPAÑIA ESPAÑOLA DE PETROLEOS SAU  A28003119
# 3     4                  INDUSTRIA DE DISEÑO TEXTIL SA  A15075062
# 4     5  REPSOL COMERCIAL DE PRODUCTOS PETROLIFEROS SA  A80298839
#
#            Localidad    Comunidad autónoma    Forma jurídica  Estado  \
# 0  TAVERNES BLANQUES  Comunidad Valenciana  Sociedad anonima  Activa
# 1             MADRID                Madrid  Sociedad anonima  Activa
# 2             MADRID                Madrid  Sociedad anonima  Activa
# 3            ARTEIXO               Galicia  Sociedad anonima  Activa
# 4             MADRID                Madrid  Sociedad anonima  Activa
#
#   Ultimo año disponible  Código primario CNAE 2009  \
# 0            31/12/2018                     4711.0
# ...

# %%
activas.shape
# Out:
# (27261, 283)

# %%
activas = activas.drop(['Mark'],axis=1)

# %%
comprobacion = []
for i in range(0,activas.shape[0]):
    
    comprobacion.append(activas.iloc[i,0] == i+1)

# %%
pd.DataFrame(comprobacion,columns=['Comp'])
# Out:
#         Comp
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
# 5       True
# 6       True
# 7       True
# 8       True
# 9       True
# 10      True
# 11      True
# 12      True
# 13      True
# 14      True
# 15      True
# 16      True
# 17      True
# 18      True
# 19      True
# 20      True
# 21      True
# 22      True
# 23      True
# 24      True
# 25      True
# 26      True
# 27      True
# 28      True
# 29      True
# ...      ...
# 27231  False
# 27232  False
# 27233  False
# 27234  False
# 27235  False
# 27236  False
# 27237  False
# 27238  False
# 27239  False
# 27240  False
# 27241  False
# 27242  False
# 27243  False
# 27244  False
# 27245  False
# 27246  False
# 27247  False
# 27248  False
# 27249  False
# 27250  False
# 27251  False
# 27252  False
# 27253  False
# 27254  False
# 27255  False
# 27256  False
# 27257  False
# 27258  False
# 27259  False
# 27260  False
#
# [27261 rows x 1 columns]

# %%
activas.duplicated().any()
# Out:
# True

# %%
list(activas[activas.duplicated()].index)
# Out:
# [27000]

# %%
activas = activas.drop(list(activas[activas.duplicated()].index),axis=0)

# %%
activas.shape
# Out:
# (27260, 282)

# %%
activas.to_csv('../Datasets/Activasv2.csv',index=False)

# %% [markdown]
# ## Activas 4 iteracción

# %%
activas = montardataset('../Datasets/Parcialesv3/Activas_',195)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-22-c2a3376bb08c> in <module>
# ----> 1 activas = montardataset('../Datasets/Parcialesv3/Activas_',195)
#
# <ipython-input-1-a403fdac2bf0> in montardataset(direccion, num)
#       4     cont+=1
#       5     for i in range(cont,num+1):
# ----> 6         dfaux=pd.read_csv(direccion+str(i)+'.txt',encoding = 'utf-16',index_col = False)
#       7         df = pd.concat([df,dfaux],ignore_index=True) # si no tomara la primera columna como el index
#       8
#
# ...

# %%
activas.shape
# Out:
# (97884, 283)

# %%
activas.head()
# Out:
#    Mark                            Nombre Código NIF          Localidad  \
# 0     1        EURO ASIA FRUIT IMP EXP SL  B86380011        FUENLABRADA
# 1     2                SOSA GUTIERREZ SL.  B06388029  PUEBLA DE ALCOCER
# 2     3                       HIRUKEI SL.  B75055871        ASTIGARRAGA
# 3     4  MENDOZA GASTRONOMIA COLECTIVA SL  B53334611           LA NUCIA
# 4     5                  ALESMAG GROUP SL  B98388705       MASSAMAGRELL
#
#      Comunidad autónoma     Forma jurídica  Estado Ultimo año disponible  \
# 0                Madrid  Sociedad limitada  Activa            31/12/2017
# 1           Extremadura  Sociedad limitada  Activa            31/12/2017
# 2            País Vasco  Sociedad limitada  Activa            31/12/2017
# 3  Comunidad Valenciana  Sociedad limitada  Activa            31/12/2017
# 4  Comunidad Valenciana  Sociedad limitada  Activa            31/12/2017
#
#    Código primario CNAE 2009  Ingresos de explotación EUR Últ. año disp.  ...  \
# ...

# %%
activas = activas.drop(['Mark'],axis=1)

# %%
activas.set_index('Código NIF').join(activas[activas.duplicated()].set_index('Código NIF'),
                                     on = 'Código NIF',
                                     how='inner',lsuffix='_left', rsuffix='_right').duplicated().any()
# Out:
# True

# %%
indices = []
for i in activas[activas.duplicated()]['Código NIF'].values:
    print(activas[activas['Código NIF'] == i].index)
# Out:
# Int64Index([6500, 7000], dtype='int64')
# Int64Index([6501, 7001], dtype='int64')
# Int64Index([6502, 7002], dtype='int64')
# Int64Index([6503, 7003], dtype='int64')
# Int64Index([6504, 7004], dtype='int64')
# Int64Index([6505, 7005], dtype='int64')
# Int64Index([6506, 7006], dtype='int64')
# Int64Index([6507, 7007], dtype='int64')
# Int64Index([6508, 7008], dtype='int64')
# Int64Index([6509, 7009], dtype='int64')
# Int64Index([6510, 7010], dtype='int64')
# Int64Index([6511, 7011], dtype='int64')
# Int64Index([6512, 7012], dtype='int64')
# Int64Index([6513, 7013], dtype='int64')
# Int64Index([6514, 7014], dtype='int64')
# Int64Index([6515, 7015], dtype='int64')
# Int64Index([6516, 7016], dtype='int64')
# Int64Index([6517, 7017], dtype='int64')
# Int64Index([6518, 7018], dtype='int64')
# Int64Index([6519, 7019], dtype='int64')
# Int64Index([6520, 7020], dtype='int64')
# Int64Index([6521, 7021], dtype='int64')
# Int64Index([6522, 7022], dtype='int64')
# ...

# %%
activas.iloc[42500:43500,:]
# Out:
#                                                   Nombre Código NIF  \
# 42500                                         VILABOY SL  B33051160
# 42501                              JARDINERIA SANCHEZ SL  B61456075
# 42502                        RCM SERVICIOS PALENTINOS SL  B34105528
# 42503               UTRERANA PANADERA SOCIEDAD LIMITADA.  B41058496
# 42504                  SUCESORES DE BACALAOS NORDICOS SL  B50571553
# 42505                                        NEW LIMP SL  B41529843
# 42506                                SEGURAUTO ARAHAL SL  B91410787
# 42507                                   MERCAPINTURAS SL  B04101366
# 42508                                 DESGUACE GARCIA SL  B91221226
# 42509          VITICULTORS DEL PRIORAT SOCIEDAD LIMITADA  B43540798
# 42510                                 LOYEV PONT 2003 SL  B30593453
# 42511                  MENCAR LOGISTIC SOCIEDAD LIMITADA  B39735386
# 42512                                     COTILEDON S.A.  A08857864
# ...

# %%
activas.iloc[7490:7900,:]
# Out:
#                                                  Nombre Código NIF  \
# 7490                            IMPORT TRUCKS EUROPE SL  B14443931
# 7491               INSTALACIONES AGROPECUARIAS COSMA SL  B31192644
# 7492                          TRANSPORTES MAESTRILLO SL  B30455372
# 7493               SUMINISTROS AGRICOLAS DEL VALLE S.L.  B21276258
# 7494                                 MAURO CELENQUE SL.  B66224643
# 7495                            BITBAN TECHNOLOGIES SL.  B85645828
# 7496                      SOFMI ESTANQUIDAD INTEGRAL SL  B96724752
# 7497                                         ININJUA SL  B35563170
# 7498  DELATIERRA DISTRIBUCION TIENDA Y CLUB DE VINOS...  B91306977
# 7499              DOMUS RENOVA HOMES SOCIEDAD LIMITADA.  B76184449
# 7500                            TALLERES EL FONDRIGO SA  A33050790
# 7501                             COMERCIAL DINAMIC'S SL  B17095647
# 7502                     ALMACENES LUIS FDEZ GALLEGO SL  B24557472
# ...

# %%
activas.duplicated().any()
# Out:
# False

# %%
import pandas as pd
activas = montardataset('../Datasets/parcial_final/activas_',46)

# %%
activa = activas.drop(['Mark'],axis=1)
activa.head()
# Out:
#                                          Nombre Código NIF  Localidad  \
# 0                                  ANECOOP S.C.  F46099222   VALENCIA
# 1  SAMVARDHANA MOTHERSON PEGUFORM BARCELONA SLU  B61134516    POLINYA
# 2            CARNIQUES DE JUIA SOCIEDAD ANONIMA  A17135583       JUIA
# 3                                GESTERNOVA, SA  A84337849     MADRID
# 4                 COMPAÑIA LOGISTICA ACOTRAL SA  A29094679  ANTEQUERA
#
#      Comunidad autónoma     Forma jurídica  Estado Ultimo año disponible  \
# 0  Comunidad Valenciana        Cooperativa  Activa            30/09/2017
# 1              Cataluña  Sociedad limitada  Activa            31/03/2018
# 2              Cataluña   Sociedad anonima  Activa            31/12/2017
# 3                Madrid   Sociedad anonima  Activa            31/12/2017
# 4             Andalucía   Sociedad anonima  Activa            31/12/2017
#
#    Código primario CNAE 2009  Ingresos de explotación EUR Últ. año disp.  \
# ...

# %%
activa.duplicated().any()
# Out:
# False

# %%
activas['Incidencias Judiciales'].isnull().sum()
# Out:
# 18762

# %%
activa.to_csv('prueba.csv',index=False)

# %%
prueba = pd.read_csv('prueba.csv',decimal=',')

# %%
prueba['Ingresos de explotación EUR Últ. año disp.'].astype(float)
# Out:
# 0        601192810.0
# 1        509678000.0
# 2        324935164.0
# 3        316309770.0
# 4        299636404.0
# 5        293423362.0
# 6        269068154.0
# 7        263455774.0
# 8        263449398.0
# 9        242903542.0
# 10       225482857.0
# 11       219973353.0
# 12       218897000.0
# 13       207378859.0
# 14       206114000.0
# 15       199078000.0
# 16       186360347.0
# 17       175235292.0
# 18       168495994.0
# 19       166133157.0
# 20       165150854.0
# 21       163937935.0
# 22       159481716.0
# 23       158029774.0
# 24       155631250.0
# 25       154956000.0
# 26       154615004.0
# 27       142272871.0
# 28       141282201.0
# 29       140627149.0
#             ...
# 22728            NaN
# 22729            NaN
# 22730            NaN
# 22731            NaN
# 22732            NaN
# 22733            NaN
# 22734            NaN
# 22735            NaN
# 22736            NaN
# 22737            NaN
# 22738            NaN
# 22739            NaN
# ...

# %%
import pandas as pd
activas = pd.read_csv('../Datasets/Activas_v4.csv',decimal=',')

# %%
activas.head()
# Out:
#                              Nombre Código NIF          Localidad  \
# 0        EURO ASIA FRUIT IMP EXP SL  B86380011        FUENLABRADA
# 1                SOSA GUTIERREZ SL.  B06388029  PUEBLA DE ALCOCER
# 2                       HIRUKEI SL.  B75055871        ASTIGARRAGA
# 3  MENDOZA GASTRONOMIA COLECTIVA SL  B53334611           LA NUCIA
# 4                  ALESMAG GROUP SL  B98388705       MASSAMAGRELL
#
#      Comunidad autónoma     Forma jurídica  Estado Ultimo año disponible  \
# 0                Madrid  Sociedad limitada  Activa            31/12/2017
# 1           Extremadura  Sociedad limitada  Activa            31/12/2017
# 2            País Vasco  Sociedad limitada  Activa            31/12/2017
# 3  Comunidad Valenciana  Sociedad limitada  Activa            31/12/2017
# 4  Comunidad Valenciana  Sociedad limitada  Activa            31/12/2017
#
#    Código primario CNAE 2009 Ingresos de explotación EUR Últ. año disp.  \
# ...

# %%
import numpy as np
indices = [i for i in range(activas.shape[0])]
np.random.shuffle(indices)

# %%
ind = indices[:24000]

# %%
import matplotlib.pyplot as plt

# %%
plt.hist(indices[:24000])
# Out:
# (array([2398., 2391., 2442., 2363., 2421., 2413., 2500., 2304., 2379.,
#         2389.]),
#  array([2.00000e+00, 9.78990e+03, 1.95778e+04, 2.93657e+04, 3.91536e+04,
#         4.89415e+04, 5.87294e+04, 6.85173e+04, 7.83052e+04, 8.80931e+04,
#         9.78810e+04]),
#  <a list of 10 Patch objects>)

# %%
pd.DataFrame(activas.iloc[ind[],:].values,columns=activas.columns)
# Out:
#                                                   Nombre Código NIF  \
# 0                 PINTURAS Y DECORACION TOMAS MURILLO SL  B14459606
# 1                                       INTEGRATILES SL.  B12917829
# 2                                          SIG MURCIA SL  B73267254
# 3                   GUDAYOL AUTO TALLER SOCIEDAD ANONIMA  A17125790
# 4                                    IMPRENTA RIOJANA SL  B26264028
# 5                     EXTRACCIONES Y LIMPIEZAS MAR-MI SL  B96008099
# 6                    BORRAS BROKER DE SEGUROS Y DEMAS SL  B96853163
# 7                     TALLERES DACASOL SOCIEDAD LIMITADA  B13333497
# 8      ESPECTACULOS TOMAS TODO PARA EL OCIO Y LA DIVE...  B26328765
# 9                                             FERPUNT SA  A58612672
# 10                                    ASSESSORIA TODA SL  B61079257
# 11                 EUROCONFORT SISTEMAS INMOBILIARIOS SL  B61524732
# 12                                          TRADEPACK SL  B01058205
# ...
